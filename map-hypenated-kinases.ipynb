# %%
library('dplyr')
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library('tidyr')

# %%
df = read.csv('/home/jovyan/work/Downloads/output.csv' )

# %%
head(df)
# Out:
#   X Just_Kinase Kinase      Result  No_Greek    No_Space    sp1   sp2   sp3
# 1 1 RET         RET_G691S   100.015 RET_G691S   RET_G691S   RET   G691S NA
# 2 2 DDR2        DDR2_N456S   99.770 DDR2_N456S  DDR2_N456S  DDR2  N456S NA
# 3 3 NTRK3       NTRK3_G696A  99.420 NTRK3_G696A NTRK3_G696A NTRK3 G696A NA
# 4 4 AXL         AXL          98.800 AXL         AXL         AXL   NA    NA
# 5 5 DDR2        DDR2         98.195 DDR2        DDR2        DDR2  NA    NA
# 6 6 MET         MET          97.565 MET         MET         MET   NA    NA
#   HGNC_ID   SYMBOL
# 1 HGNC:9967 RET
# 2 HGNC:2731 DDR2
# 3 HGNC:8033 NTRK3
# 4 HGNC:905  AXL
# 5 HGNC:2731 DDR2
# 6 HGNC:7029 MET

# %%
df_copy <- data.frame(df)

# %%
df_subset <- df %>% filter(grepl(paste(coexpressions, collapse = "|"), Kinase)) %>% separate_rows(Kinase, sep = '-') %>% distinct(Result, Kinase, .keep_all=T )
df_subset
# Out:
#    X   Just_Kinase          Kinase Result No_Greek
# 1  239 PRKAA2-PRKAB1-PRKAG2 PRKAA2  1.780 PRKAA2-PRKAB1-PRKAG2
# 2  239 PRKAA2-PRKAB1-PRKAG2 PRKAB1  1.780 PRKAA2-PRKAB1-PRKAG2
# 3  239 PRKAA2-PRKAB1-PRKAG2 PRKAG2  1.780 PRKAA2-PRKAB1-PRKAG2
# 4  249 PRKAA1-PRKAB2-PRKAG2 PRKAA1  1.255 PRKAA1-PRKAB2-PRKAG2
# 5  249 PRKAA1-PRKAB2-PRKAG2 PRKAB2  1.255 PRKAA1-PRKAB2-PRKAG2
# 6  249 PRKAA1-PRKAB2-PRKAG2 PRKAG2  1.255 PRKAA1-PRKAB2-PRKAG2
# 7  256 PRKAA1-PRKAB2-PRKAG3 PRKAA1  0.955 PRKAA1-PRKAB2-PRKAG3
# 8  256 PRKAA1-PRKAB2-PRKAG3 PRKAB2  0.955 PRKAA1-PRKAB2-PRKAG3
# 9  256 PRKAA1-PRKAB2-PRKAG3 PRKAG3  0.955 PRKAA1-PRKAB2-PRKAG3
# 10 310 PRKAA2-PRKAB1-PRKAG3 PRKAA2 -1.160 PRKAA2-PRKAB1-PRKAG3
# 11 310 PRKAA2-PRKAB1-PRKAG3 PRKAB1 -1.160 PRKAA2-PRKAB1-PRKAG3
# 12 310 PRKAA2-PRKAB1-PRKAG3 PRKAG3 -1.160 PRKAA2-PRKAB1-PRKAG3
#    No_Space             sp1    sp2    sp3    HGNC_ID   SYMBOL
# 1  PRKAA2-PRKAB1-PRKAG2 PRKAA2 PRKAB1 PRKAG2 HGNC:9377 PRKAA2
# ...

# %%
bind_rows(df_subset, df %>% filter(!grepl(paste(coexpressions, collapse="|"), Kinase)))
# Out:
#     X   Just_Kinase          Kinase         Result  No_Greek
# 1   239 PRKAA2-PRKAB1-PRKAG2 PRKAA2          1.780  PRKAA2-PRKAB1-PRKAG2
# 2   239 PRKAA2-PRKAB1-PRKAG2 PRKAB1          1.780  PRKAA2-PRKAB1-PRKAG2
# 3   239 PRKAA2-PRKAB1-PRKAG2 PRKAG2          1.780  PRKAA2-PRKAB1-PRKAG2
# 4   249 PRKAA1-PRKAB2-PRKAG2 PRKAA1          1.255  PRKAA1-PRKAB2-PRKAG2
# 5   249 PRKAA1-PRKAB2-PRKAG2 PRKAB2          1.255  PRKAA1-PRKAB2-PRKAG2
# 6   249 PRKAA1-PRKAB2-PRKAG2 PRKAG2          1.255  PRKAA1-PRKAB2-PRKAG2
# 7   256 PRKAA1-PRKAB2-PRKAG3 PRKAA1          0.955  PRKAA1-PRKAB2-PRKAG3
# 8   256 PRKAA1-PRKAB2-PRKAG3 PRKAB2          0.955  PRKAA1-PRKAB2-PRKAG3
# 9   256 PRKAA1-PRKAB2-PRKAG3 PRKAG3          0.955  PRKAA1-PRKAB2-PRKAG3
# 10  310 PRKAA2-PRKAB1-PRKAG3 PRKAA2         -1.160  PRKAA2-PRKAB1-PRKAG3
# 11  310 PRKAA2-PRKAB1-PRKAG3 PRKAB1         -1.160  PRKAA2-PRKAB1-PRKAG3
# 12  310 PRKAA2-PRKAB1-PRKAG3 PRKAG3         -1.160  PRKAA2-PRKAB1-PRKAG3
# ...

# %%
df[249:255, ]
# Out:
#     X   Just_Kinase          Kinase               Result No_Greek
# 249 249 PRKAA1-PRKAB2-PRKAG2 PRKAA1-PRKAB2-PRKAG2 1.255  PRKAA1-PRKAB2-PRKAG2
# 250 250 MARK2                MARK2                1.220  MARK2
# 251 251 GRK6                 GRK6                 1.185  GRK6
# 252 252 TGFBR1               TGFBR1               1.060  TGFBR1
# 253 253 DAPK1                DAPK1                1.045  DAPK1
# 254 254 STK38L               STK38L               0.995  STK38L
# 255 255 MAPKAPK5             MAPKAPK5             0.980  MAPKAPK5
#     No_Space             sp1      sp2    sp3    HGNC_ID    SYMBOL
# 249 PRKAA1-PRKAB2-PRKAG2 PRKAA1   PRKAB2 PRKAG2 HGNC:9376  PRKAA1
# 250 MARK2                MARK2    NA     NA     HGNC:3332  MARK2
# 251 GRK6                 GRK6     NA     NA     HGNC:4545  GRK6
# 252 TGFBR1               TGFBR1   NA     NA     HGNC:11772 TGFBR1
# 253 DAPK1                DAPK1    NA     NA     HGNC:2674  DAPK1
# ...

# %%
cofactors <- c('BUB1-BUB3','CDC7-DBF4','CDK12-CCNK','CDK13-CCNK','CDK14-CCNY','CDK15-CCNA2','CDK15-CCNB1','CDK16-CCNY','CDK17-CCNY','CDK17-CDK5R1','CDK18-CCNY','CDK19-CCNC','CDK1-CCNA1','CDK1-CCNA2','CDK1-CCNB1','CDK1-CCNE1','CDK20-CCNH','CDK20-CCNT1','CDK2-CCNA1','CDK2-CCNA2','CDK2-CCND1','CDK2-CCNE1','CDK2-CCNE2','CDK2-CCNO','CDK3-CCNC','CDK3-CCNE1','CDK3-CCNE2','CDK4-CCND1','CDK4-CCND2','CDK4-CCND3','CDK5-CDK5R1','CDK5-CDK5R1 (p25)','CDK6-CCND1','CDK6-CCND2','CDK6-CCND3','CDK7-CCNH','CDK7-CCNH-MNAT1','CDK8-CCNC','CDK9-CCNK','CDK9-CCNT1','CDK9-CCNT2','CSNK2A1-CSNK2B','CSNK2A2-CSNK2B','PIK3CA-PIK3R1','PIK3CA-PIK3R1 (p65a)','PIK3CA-PIK3R3','PIK3CB-PIK3R1','PIK3CB-PIK3R2','PIK3CD-PIK3R1')

# %%
cofactors
# Out:
#  [1] "BUB1-BUB3"            "CDC7-DBF4"            "CDK12-CCNK"
#  [4] "CDK13-CCNK"           "CDK14-CCNY"           "CDK15-CCNA2"
#  [7] "CDK15-CCNB1"          "CDK16-CCNY"           "CDK17-CCNY"
# [10] "CDK17-CDK5R1"         "CDK18-CCNY"           "CDK19-CCNC"
# [13] "CDK1-CCNA1"           "CDK1-CCNA2"           "CDK1-CCNB1"
# [16] "CDK1-CCNE1"           "CDK20-CCNH"           "CDK20-CCNT1"
# [19] "CDK2-CCNA1"           "CDK2-CCNA2"           "CDK2-CCND1"
# [22] "CDK2-CCNE1"           "CDK2-CCNE2"           "CDK2-CCNO"
# [25] "CDK3-CCNC"            "CDK3-CCNE1"           "CDK3-CCNE2"
# [28] "CDK4-CCND1"           "CDK4-CCND2"           "CDK4-CCND3"
# [31] "CDK5-CDK5R1"          "CDK5-CDK5R1 (p25)"    "CDK6-CCND1"
# [34] "CDK6-CCND2"           "CDK6-CCND3"           "CDK7-CCNH"
# [37] "CDK7-CCNH-MNAT1"      "CDK8-CCNC"            "CDK9-CCNK"
# [40] "CDK9-CCNT1"           "CDK9-CCNT2"           "CSNK2A1-CSNK2B"
# ...

# %%
coexpressions <- c('PRKAA1-PRKAB1-PRKAG2',
'PRKAA1-PRKAB1-PRKAG3',
'PRKAA1-PRKAB2-PRKAG1',
'PRKAA1-PRKAB2-PRKAG2',
'PRKAA1-PRKAB2-PRKAG3',
'PRKAA2-PRKAB1-PRKAG1',
'PRKAA2-PRKAB1-PRKAG2',
'PRKAA2-PRKAB1-PRKAG3',
'PRKAA2-PRKAB2-PRKAG1',
'PRKAA2-PRKAB2-PRKAG2',
'PRKAA2-PRKAB2-PRKAG3'
 )

# %%
df %>%
  filter() %>%
  separate_rows(Kinase, sep = "_")

# %%
length(cofactors)
# Out:
# [1] 49

# %%
df %>% filter(grepl(pattern = 'CDK3', x = Kinase))
# Out:
#   X   Just_Kinase Kinase     Result No_Greek   No_Space   sp1  sp2   sp3
# 1 406 CDK3        CDK3_CCNE1 1.755  CDK3_CCNE1 CDK3_CCNE1 CDK3 CCNE1 NA
# 2 411 CDK3        CDK3_CCNE2 1.660  CDK3_CCNE2 CDK3_CCNE2 CDK3 CCNE2 NA
#   HGNC_ID   SYMBOL
# 1 HGNC:1772 CDK3
# 2 HGNC:1772 CDK3

# %%
df %>%
      filter(!is.na(sp2) | !is.na(sp3), is.na(HGNC_ID)) %>%
      mutate(INDEX = row_number())
# Out:
#      X Just_Kinase Kinase Result No_Greek No_Space sp1 sp2 sp3 HGNC_ID SYMBOL
#      INDEX

# %%
?rlang::duplicate
# Out:
# duplicate                package:rlang                 R Documentation
#
# t
#
# n:
#
#      In R semantics, objects are copied by value. This means that
#      modifying the copy leaves the original object intact. Since
#      copying data in memory is an expensive operation, copies in R are
#      as lazy as possible. They only happen when the new object is
#      actually modified. However, some operations (like
#      ‘node_poke_car()’ or ‘node_poke_cdr()’) do not support
#      copy-on-write. In those cases, it is necessary to duplicate the
#      object manually in order to preserve copy-by-value semantics.
#
# e:
#
#      duplicate(x, shallow = FALSE)
#
# s:
#
#        x: Any R object. However, uncopyable types like symbols and
#           environments are returned as is (just like with <-).
#
#  shallow: This is relevant for recursive data structures like lists,
#           calls and pairlists. A shallow copy only duplicates the
# ...

# %%
?replace
# Out:
# replace                  package:base                  R Documentation
#
# r
#
# n:
#
#      ‘replace’ replaces the values in ‘x’ with indices given in ‘list’
#      by those given in ‘values’. If necessary, the values in ‘values’
#      are recycled.
#
# e:
#
#      replace(x, list, values)
#
# s:
#
#        x: vector
#
#     list: an index vector
#
#   values: replacement values
#
# e:
#
#      A vector with the values replaced.
#
# e:
#
#      ‘x’ is unchanged: remember to assign the result.
#
# s:
#
#      Becker, R. A., Chambers, J. M. and Wilks, A. R. (1988) _The New S
#      Language_.  Wadsworth & Brooks/Cole.
